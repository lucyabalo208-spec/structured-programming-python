# %% [markdown]
# # ASSIGNMENT

# %% [markdown]
# ## IF-ELSE STATEMENT

# %% [markdown]
# 1.  write a program that will take a number from user and will display wether the number is evenor odd. Use if-else statement.

# %%
number = int(input("Enter number"))
if number%2 == 0:
    print ("The number is even")
else:
    print ("The number is odd")
# Out:
# The number is odd

# %% [markdown]
# 2. Write a program that ask the user to enter a length in centimeters. if the user enters a negative length the program should tell the user that the entry is invalid. Otherwise the programm should convert the length to inches and print out the result. There are 2.54 centimeters in a inch.

# %%
length = float(input('Enter length in centimeters'))
if length <0:
    print('invalid entr, length can not be negative')
else:
    inches = length/2.54
    print('length in inches:', inches)

# %% [markdown]
# 3. Writ a program that ask the user for two numbers and prints 'Entered number are closed', if the number differ within 10 units feom each other and prints 'Entered numbers are not closed!, otherwise. Use if-else statement.

# %%
number1 = int(input('Enter number 1'))
number2 = int(input('Enter number 2'))
if range ==10:
    print('Entered number are closed!')
else:
    print('Entered number are Not closed!')
# Out:
# Entered number are Not closed!

# %% [markdown]
# 4.Write a program that ask the user for an hour between 1 and 12, and then asks them to enter am or pm. The program then shows the hour in 24-Hour format.

# %%
hour = int(input('Enter hour(1-12)'))
period = input('Enter am or pm')
if period == "am":
    if hour == 12:
        hour = 0
else:
    if hour != 12:    
        hour = hour + 12   
print('24-hour format:', hour)
# Out:
# 24-hour format: 25

# %% [markdown]
#  SQUARE ROOT OF A NUMBER
#
# 5. Write a program that will take a number from user and will display the square root of it.

# %%
number = int(input("Enter number: "))
import math
if number>=0:
    result = math.sqrt(number)
    print("squrae root is:", result)
else:
    number = number * -1
    result = math.sqrt(number)
    print("square root is:", j)
# Out:
# squrae root is: 2.0

# %%
number = float(input("Enter number: "))
import math
if number<=0:
    print("squrae root is:", result)
else:
    number = number * -1
    result = math.sqrt(number)
    print("square root is:", j)
# Out:
# squrae root is: 6.0

# %% [markdown]
# 6. Write a program that will take two numbers as input(say a and b)and will show their ratio at output (a/b). As you know that division by zero is not possibleand a run- time error occurs in an attempt to divide by zero.

# %%
a = eval(input('Enter first number: '))
b = eval(input('Enter second number: '))
if b == 0:
    print('division by zero is not possible')
else:
    ratio = (a/b)
    print(' The ratio is:',ratio)
# Out:
#  The ratio is: 0.5

# %% [markdown]
# 7. A perfect square  is one whose square root is an interger e.g. 16 is perfect square and 15 is not. Write a program that will take a number from user and will display whether it is perfect square or not.

# %%
number = int(input('Enter number: '))

if number >=0 and math.sqrt(number). is_integer():  
    print('It is a perfect square')
else:
    print('It is not a perfect square')
# Out:
# It is not a perfect square

# %% [markdown]
# # TASK 8

# %%
marks1 = float(input("Enter marks for subject 1: "))
marks2 = float(input("Enter marks for subject 2: "))
marks3 = float(input("Enter marks for subject 3: "))
marks4 = float(input("Enter marks for subject 4: "))
marks5 = float(input("Enter marks for subject 5: "))

average = (marks1 + marks2 + marks3 + marks4 + marks5) / 5

print("Average of five subject marks is:", average)

if average >= 80:
    print("You are an outstanding student.")
elif average >= 70 and 80:
    print("You are a good student.")
elif average >= 60 and 70:
    print("You are an average student.")
elif average >= 50 and 60:
    print("You are a below-average student.")
elif average >= 40 and 50:
    print("You are a poor student.")
else:
    print("You need extraordinary efforts.")
# Out:
# Average of five subject marks is: 83.4
# You are an outstanding student.

# %% [markdown]
# TASK 9

# %%
import math

a = float(input("Enter first side: "))
b = float(input("Enter second side: "))
c = float(input("Enter third side: "))

if a + b > c and a + c > b and b + c > a:
    s = (a + b + c) / 2
    area = math.sqrt(s * (s - a) * (s - b) * (s - c))
    print("Area of triangle is:", area)
else:
    print("Triangle is invalid.")
# Out:
# Triangle is invalid.

# %% [markdown]
# # TASK 10
# ## Write a program that will take three numbers as input and will print the maximum of the three numbers at at output. you have to use three if statement

# %%
a = int(input("Enter first integer: "))
b = int(input("Enter second integer: "))
c = int(input("Enter third integer: "))

largest = a

if b > largest:
    largest = b

if c > largest:
    largest = c

if largest == a:
    print(a, "is the largest")
    
if largest == b:
    print(b, "is the largest")
    
if largest == c:
    print(c, "is the largest")
# Out:
# 68 is the largest

# %% [markdown]
# TASK 11
# A company insures its employees in the following cases:
#     if the employee is married
#     if the employee is unmarried, male and above 30 years of age
#     if the employee is unmarried, female and above 25 years of 25 years of age
# write a programwhich takes marital status, gender and age as input from user. After checking the given conditions, the output of the program will a message stating whether he/she is eligible for insurance or not.

# %%
S = input("Enter your marital status (M/U): ")
G = input("Enter your gender (M/F): ")
A = int(input("Enter your age: "))

if S == "M" or (S == "U" and G == "M" and A > 30) or (S == "U" and G == "F" and A > 25):
    print("Congratulations!")
    print("You are eligible for the insurance.")
else:
    print("We are Sorry!")
    print("You are not eligible for the insurance.")
# Out:
# We are Sorry!
# You are not eligible for the insurance.
